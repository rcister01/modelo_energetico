# %% [markdown]
# ## Analisis del  Dataset reducido (4,2)

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import pandas as pd
import numpy as np

# %%
X_train = pd.read_csv('../raw_data/X_train_red_4.csv')
y_train = pd.read_csv('../raw_data/y_train_red_2_target.csv')

# %%
X_train.head()
# Out:
#    Unnamed: 0  airchange_infiltration_vol_per_h  \
# 0        3151                               0.3
# 1        4019                               0.4
# 2        4194                               0.4
# 3        1825                               0.1
# 4        7363                               0.1
#
#    capacitance_kJ_perdegreK_perm3  power_VCV_kW_heat  power_VCV_kW_clim  \
# 0                            40.0              400.0              500.0
# 1                           150.0              400.0              600.0
# 2                           260.0              500.0              600.0
# 3                            20.0              400.0              600.0
# 4                            20.0              500.0              500.0
#
#    nb_occupants  nb_PCs  facade_1_thickness_2  facade_1_window_area_percent  \
# 0        1000.0  1000.0                  0.07                          45.0
# 1        1100.0  1000.0                  0.06                          40.0
# ...

# %%
y_train.head()
# Out:
#    Unnamed: 0  T_INT_OFFICE_MEN     Q_Total
# 0        3151         23.698596  22722.4910
# 1        4019         22.483340  16536.7879
# 2        4194         23.619043  28439.8360
# 3        1825         22.528464  19832.0881
# 4        7363         23.894442  26751.9070

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# (5025, 92)
# (5025, 3)

# %%
data = pd.concat([y_train,X_train])
data
# Out:
#       Unnamed: 0  T_INT_OFFICE_MEN     Q_Total  \
# 0           3151         23.698596  22722.4910
# 1           4019         22.483340  16536.7879
# 2           4194         23.619043  28439.8360
# 3           1825         22.528464  19832.0881
# 4           7363         23.894442  26751.9070
# ...          ...               ...         ...
# 5020        5191               NaN         NaN
# 5021        5226               NaN         NaN
# 5022        5390               NaN         NaN
# 5023         860               NaN         NaN
# 5024        7270               NaN         NaN
#
#       airchange_infiltration_vol_per_h  capacitance_kJ_perdegreK_perm3  \
# 0                                  NaN                             NaN
# 1                                  NaN                             NaN
# 2                                  NaN                             NaN
# 3                                  NaN                             NaN
# ...

# %%
columns_names = data.columns.values
columns_names_list = list(columns_names)
columns_names_list
# Out:
# ['Unnamed: 0',
#  'T_INT_OFFICE_MEN',
#  'Q_Total',
#  'airchange_infiltration_vol_per_h',
#  'capacitance_kJ_perdegreK_perm3',
#  'power_VCV_kW_heat',
#  'power_VCV_kW_clim',
#  'nb_occupants',
#  'nb_PCs',
#  'facade_1_thickness_2',
#  'facade_1_window_area_percent',
#  'facade_2_thickness_2',
#  'facade_2_window_area_percent',
#  'facade_3_thickness_2',
#  'facade_3_window_area_percent',
#  'facade_4_thickness_2',
#  'facade_4_window_area_percent',
#  'roof_thickness_2',
#  'ground_thickness_2',
#  'init_day',
#  'init_month',
#  'init_year',
#  'ac_t_conf_morning_1',
#  'ac_t_conf_morning_2',
#  'ac_t_conf_afternoon_1',
#  'ac_t_conf_night_1',
#  'ac_t_red_morning_1',
#  'ac_t_red_morning_2',
#  'ac_t_red_afternoon_1',
#  'ac_t_red_night_1',
#  'ac_mask_morning_1',
#  'ac_mask_morning_2',
#  'ac_mask_afternoon_1',
#  'ac_mask_night_1',
#  'heat_t_conf_morning_1',
#  'heat_t_conf_morning_2',
#  'heat_t_conf_afternoon_1',
#  'heat_t_conf_night_1',
#  'heat_t_red_morning_1',
# ...

# %%
corr = data.corr()
corr.head(50)
# Out:
#                                   Unnamed: 0  T_INT_OFFICE_MEN   Q_Total  \
# Unnamed: 0                          1.000000         -0.040218 -0.015058
# T_INT_OFFICE_MEN                   -0.040218          1.000000  0.680883
# Q_Total                            -0.015058          0.680883  1.000000
# airchange_infiltration_vol_per_h    0.016143               NaN       NaN
# capacitance_kJ_perdegreK_perm3     -0.017372               NaN       NaN
# power_VCV_kW_heat                   0.006807               NaN       NaN
# power_VCV_kW_clim                   0.010555               NaN       NaN
# nb_occupants                       -0.012675               NaN       NaN
# nb_PCs                              0.012564               NaN       NaN
# facade_1_thickness_2                0.011779               NaN       NaN
# facade_1_window_area_percent       -0.007619               NaN       NaN
# facade_2_thickness_2               -0.035483               NaN       NaN
# ...

# %%
dtcr = data[[
 'T_INT_OFFICE_MEN','airchange_infiltration_vol_per_h',
 'capacitance_kJ_perdegreK_perm3',
 'power_VCV_kW_heat',
 'power_VCV_kW_clim',
 'nb_occupants',
 'nb_PCs',
 'facade_1_thickness_2',
 'facade_1_window_area_percent',
 'facade_2_thickness_2',
 'facade_2_window_area_percent',
 'facade_3_thickness_2',
 'facade_3_window_area_percent',
 'facade_4_thickness_2',
 'facade_4_window_area_percent',
 'roof_thickness_2',
 'ground_thickness_2'
]]

# %%
corr = dtcr.corr()
plt.figure(figsize=(15,15))
sns.heatmap(corr, 
        xticklabels=corr.columns,
        yticklabels=corr.columns,
        cmap= "RdYlGn")
# Out:
# <AxesSubplot:>

# %%
dtcr = data[[
    
 'T_INT_OFFICE_MEN',
 'ac_t_conf_morning_1',
 'ac_t_conf_morning_2',
 'ac_t_conf_afternoon_1',
 'ac_t_conf_night_1',
 'ac_t_red_morning_1',
 'ac_t_red_morning_2',
 'ac_t_red_afternoon_1',
 'ac_t_red_night_1',
 'ac_mask_morning_1',
 'ac_mask_morning_2',
 'ac_mask_afternoon_1',
 'ac_mask_night_1',
    
]]

# %%
corr = dtcr.corr()
plt.figure(figsize=(15,15))
sns.heatmap(corr, 
        xticklabels=corr.columns,
        yticklabels=corr.columns,
        cmap= "RdYlGn")
# Out:
# <AxesSubplot:>

# %%
dtcr = data [[
 'T_INT_OFFICE_MEN',
 'heat_t_conf_morning_1',
 'heat_t_conf_morning_2',
 'heat_t_conf_afternoon_1',
 'heat_t_conf_night_1',
 'heat_t_red_morning_1',
 'heat_t_red_morning_2',
 'heat_t_red_afternoon_1',
 'heat_t_red_night_1',
 'heat_mask_morning_1',
 'heat_mask_morning_2',
 'heat_mask_afternoon_1',
 'heat_mask_night_1',
 'ventilation_t_morning_1',
 'ventilation_t_morning_2',
 'ventilation_t_afternoon_1',
 'ventilation_t_night_1',
 'ventilation_vol_morning_1',
 'ventilation_vol_morning_2',
 'ventilation_vol_afternoon_1',
 'ventilation_vol_night_1',
 'ventilation_mask_morning_1',
 'ventilation_mask_morning_2',
 'ventilation_mask_afternoon_1',
 'ventilation_mask_night_1',
 'occupancy_morning_1',
 'occupancy_morning_2',
 'occupancy_afternoon_1',
 'occupancy_night_1',
    
]]

# %%
corr = dtcr.corr()
plt.figure(figsize=(15,15))
sns.heatmap(corr, 
        xticklabels=corr.columns,
        yticklabels=corr.columns,
        cmap= "RdYlGn")
# Out:
# <AxesSubplot:>

# %%
dtcr = data [[
    
 'T_INT_OFFICE_MEN',  
 'pc_on_mask_morning_1',
 'pc_on_mask_morning_2',
 'pc_on_mask_afternoon_1',
 'pc_on_mask_night_1',
 'DNI_morning_1',
 'DNI_morning_2',
 'DNI_afternoon_1',
 'DNI_night_1',
 'IBEAM_H_morning_1',
 'IBEAM_H_morning_2',
 'IBEAM_H_afternoon_1',
 'IBEAM_H_night_1',
 'IBEAM_N_morning_1',
 'IBEAM_N_morning_2',
 'IBEAM_N_afternoon_1',
 'IBEAM_N_night_1',
 'IDIFF_H_morning_1',
 'IDIFF_H_morning_2',
 'IDIFF_H_afternoon_1',
 'IDIFF_H_night_1',
 'IGLOB_H_morning_1',
 'IGLOB_H_morning_2',
 'IGLOB_H_afternoon_1',
 'IGLOB_H_night_1',
 'RHUM_morning_1',
 'RHUM_morning_2',
 'RHUM_afternoon_1',
 'RHUM_night_1',
 'TAMB_morning_1',
 'TAMB_morning_2',
 'TAMB_afternoon_1',
 'TAMB_night_1']
    
]

# %%
corr = dtcr.corr()
plt.figure(figsize=(20,20))
sns.heatmap(corr, 
        xticklabels=corr.columns,
        yticklabels=corr.columns,
        cmap= "RdYlGn")
# Out:
# <AxesSubplot:>

# %%
dtcr = data [[ 
 'Q_Total',
 'airchange_infiltration_vol_per_h',
 'capacitance_kJ_perdegreK_perm3',
 'power_VCV_kW_heat',
 'power_VCV_kW_clim',
 'nb_occupants',
 'nb_PCs',
 'facade_1_thickness_2',
 'facade_1_window_area_percent',
 'facade_2_thickness_2',
 'facade_2_window_area_percent',
 'facade_3_thickness_2',
 'facade_3_window_area_percent',
 'facade_4_thickness_2',
 'facade_4_window_area_percent',
 'roof_thickness_2',
 'ground_thickness_2',
 'init_day',
 'init_month',
 'init_year',
             
     ]]

# %%
corr = dtcr.corr()
plt.figure(figsize=(20,20))
sns.heatmap(corr, 
        xticklabels=corr.columns,
        yticklabels=corr.columns,
        cmap= "RdYlGn")
# Out:
# <AxesSubplot:>

# %%
dtcr = data [[ 
 'Q_Total',
 'ac_t_conf_morning_1',
 'ac_t_conf_morning_2',
 'ac_t_conf_afternoon_1',
 'ac_t_conf_night_1',
 'ac_t_red_morning_1',
 'ac_t_red_morning_2',
 'ac_t_red_afternoon_1',
 'ac_t_red_night_1',
 'ac_mask_morning_1',
 'ac_mask_morning_2',
 'ac_mask_afternoon_1',
 'ac_mask_night_1',

]]

# %%
corr = dtcr.corr()
plt.figure(figsize=(15,15))
sns.heatmap(corr, 
        xticklabels=corr.columns,
        yticklabels=corr.columns,
        cmap= "RdYlGn")
# Out:
# <AxesSubplot:>

# %%
dtcr = data [[
 'Q_Total',
 'heat_t_conf_morning_1',
 'heat_t_conf_morning_2',
 'heat_t_conf_afternoon_1',
 'heat_t_conf_night_1',
 'heat_t_red_morning_1',
 'heat_t_red_morning_2',
 'heat_t_red_afternoon_1',
 'heat_t_red_night_1',
 'heat_mask_morning_1',
 'heat_mask_morning_2',
 'heat_mask_afternoon_1',
 'heat_mask_night_1',
 'ventilation_t_morning_1',
 'ventilation_t_morning_2',
 'ventilation_t_afternoon_1',
 'ventilation_t_night_1',
 'ventilation_vol_morning_1',
 'ventilation_vol_morning_2',
 'ventilation_vol_afternoon_1',
 'ventilation_vol_night_1',
 'ventilation_mask_morning_1',
 'ventilation_mask_morning_2',
 'ventilation_mask_afternoon_1',
 'ventilation_mask_night_1',
 'occupancy_morning_1',
 'occupancy_morning_2',
 'occupancy_afternoon_1',
 'occupancy_night_1',
    
]]

# %%
corr = dtcr.corr()
plt.figure(figsize=(15,15))
sns.heatmap(corr, 
        xticklabels=corr.columns,
        yticklabels=corr.columns,
        cmap= "RdYlGn")
# Out:
# <AxesSubplot:>

# %%
dtcr = data [[
 'Q_Total',
 'pc_on_mask_morning_1',
 'pc_on_mask_morning_2',
 'pc_on_mask_afternoon_1',
 'pc_on_mask_night_1',
 'DNI_morning_1',
 'DNI_morning_2',
 'DNI_afternoon_1',
 'DNI_night_1',
 'IBEAM_H_morning_1',
 'IBEAM_H_morning_2',
 'IBEAM_H_afternoon_1',
 'IBEAM_H_night_1',
 'IBEAM_N_morning_1',
 'IBEAM_N_morning_2',
 'IBEAM_N_afternoon_1',
 'IBEAM_N_night_1',
 'IDIFF_H_morning_1',
 'IDIFF_H_morning_2',
 'IDIFF_H_afternoon_1',
 'IDIFF_H_night_1',
 'IGLOB_H_morning_1',
 'IGLOB_H_morning_2',
 'IGLOB_H_afternoon_1',
 'IGLOB_H_night_1',
 'RHUM_morning_1',
 'RHUM_morning_2',
 'RHUM_afternoon_1',
 'RHUM_night_1',
 'TAMB_morning_1',
 'TAMB_morning_2',
 'TAMB_afternoon_1',
 'TAMB_night_1'
    
    
]]

# %%
corr = dtcr.corr()
plt.figure(figsize=(15,15))
sns.heatmap(corr, 
        xticklabels=corr.columns,
        yticklabels=corr.columns,
        cmap= "RdYlGn")
# Out:
# <AxesSubplot:>

# %%
dtcr = data [[ 
    
 'Q_Total',
 'IBEAM_H_morning_1',
 'IBEAM_H_morning_2',
 'IBEAM_H_afternoon_1',
 'IBEAM_H_night_1',
 'IBEAM_N_morning_1',
 'IBEAM_N_morning_2',
 'IBEAM_N_afternoon_1',
 'IBEAM_N_night_1',
 'IDIFF_H_morning_1',
 'IDIFF_H_morning_2',
 'IDIFF_H_afternoon_1',
 'IDIFF_H_night_1',
 'IGLOB_H_morning_1',
 'IGLOB_H_morning_2',
 'IGLOB_H_afternoon_1',
 'IGLOB_H_night_1',
 'RHUM_morning_1',
 'RHUM_morning_2',
 'RHUM_afternoon_1',
 'RHUM_night_1',
 'TAMB_morning_1',
 'TAMB_morning_2',
 'TAMB_afternoon_1',
 'TAMB_night_1'

]]

# %%
corr = dtcr.corr()
plt.figure(figsize=(15,15))
sns.heatmap(corr, 
        xticklabels=corr.columns,
        yticklabels=corr.columns,
        cmap= "RdYlGn")
# Out:
# <AxesSubplot:>
